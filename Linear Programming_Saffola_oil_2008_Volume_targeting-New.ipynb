# %%
import pandas as pd
import numpy as np
from pulp import *
import warnings
warnings.filterwarnings("ignore")
    
sim_input=pd.read_excel("Optimization_Input_Saffola_oil.xlsx")
#model_output['SPEND'] = model_output['SPEND']/6
sim_input['VALUE'] = sim_input['SPEND']*sim_input['ROI']
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# sim_input.rename(columns = {'Platform': 'FEATURE'}, inplace = True)

# %%
Total_spend =  sim_input[sim_input['Event_tag'] == 0]['SPEND'].sum()
Total_value = sim_input[sim_input['Event_tag'] == 0]['VALUE'].sum()
print(Total_spend,Total_value)
# Out:
# 30.345931366666665 66.137809116

# %%
Total_spend =  sim_input[sim_input['Event_tag'] == 1]['SPEND'].sum()
Total_value = sim_input[sim_input['Event_tag'] == 1]['VALUE'].sum()
print(Total_spend,Total_value)
# Out:
# 25.94400883333333 57.19768650666667

# %%
format1 = {'Format':['Youtube Spend', 'Google Display Spend', 'G Adwords Spend', 'Facebook Spend', 'Instagram Spend', np.NaN, np.NaN, 'AMS Search Display', 'AMS Search Product', 'AMS Search Brand',
                 'AMS Display', np.NaN, np.NaN, np.NaN, np.NaN, 'JBP Spends', np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN,
                 np.NaN, np.NaN, np.NaN, np.NaN, 'Amazon', 'Flipkart', 'Big Basket']}

format1 =pd.DataFrame(format1)

# %%
print(sim_input)
# Out:
#                      FEATURE      SPEND  Event_tag   ROI      VALUE
# 0             Facebook Spend   2.784327          1  2.70   7.517682
# 1            Instagram Spend   0.416003          1  0.00   0.000000
# 2            G Adwords Spend   4.427988          1  0.44   1.948315
# 3              YouTube Spend   4.746917          1  2.30  10.917908
# 4              Display Spend   0.000143          1  0.00   0.000000
# 5      Facebook Collab Spend   3.077647          1  4.72  14.526492
# 6     Instagram Collab Spend   0.366750          1  0.00   0.000000
# 7          AMS Display Spend   5.666667          1  0.00   0.000000
# 8     AMS Brand Search Spend   1.028545          1  5.00   5.142727
# 9   AMS Product Search Spend   3.428912          1  5.00  17.144562
# 10  AMS Search Display Spend   0.000110          1  0.00   0.000000
# 11            Facebook Spend   4.344813          0  2.70  11.730996
# 12           Instagram Spend   0.651817          0  0.00   0.000000
# 13           G Adwords Spend   5.014460          0  0.44   2.206362
# 14             YouTube Spend  16.054120          0  2.30  36.924476
# 15             Display Spend   1.225527          0  0.00   0.000000
# 16     Facebook Collab Spend   0.000000          0  4.72   0.000000
# 17    Instagram Collab Spend   0.000000          0  0.00   0.000000
# 18         AMS Display Spend   0.000000          0  0.00   0.000000
# 19    AMS Brand Search Spend   0.330076          0  5.00   1.650378
# 20  AMS Product Search Spend   2.725119          0  5.00  13.625597
# 21  AMS Search Display Spend   0.000000          0  0.00   0.000000

# %%
def liner_programming_scenario(data, change_value =1, event_tag =0):
    
    sim_input = data.copy()
    temp_df =sim_input[['FEATURE', 'ROI']].drop_duplicates()
    temp_df['spend_type']=''

#     model_output['spend_type'][model_output.SPEND>=4]='hs'

    temp_df['spend_type'][sim_input.ROI==0]='ns'

#     model_output=model_output.sort_values(by=['SPEND'],ascending=False).reset_index(drop=True)
#     print(model_output)

    temp_df['upper_range']=0
    temp_df['lower_range']=0 

    #model_output['idx']=[str(i+1)+model_output.spend_type[i] for i in model_output.index]

    temp_df['upper_range'][temp_df.spend_type.str.contains('ns')]=0
    temp_df['lower_range'][temp_df.spend_type.str.contains('ns')]=0
##### Individual platform constraints 
    if event_tag ==0:
        
        Total_spend =  sim_input[sim_input['Event_tag'] == 0]['SPEND'].sum()
        Total_value = sim_input[sim_input['Event_tag'] == 0]['VALUE'].sum()
        
        temp_df['upper_range'][temp_df.FEATURE.str.contains('YouTube')]=48.2
        temp_df['lower_range'][temp_df.FEATURE.str.contains('YouTube')]=13.4
            
        temp_df['upper_range'][temp_df.FEATURE.str.contains('G Adwords')]=7.2
        temp_df['lower_range'][temp_df.FEATURE.str.contains('G Adwords')]=1.4
            
        temp_df['upper_range'][temp_df.FEATURE.str.contains('Facebook')]=10.6
        temp_df['lower_range'][temp_df.FEATURE.str.contains('Facebook')]=2.4
                      
        temp_df['upper_range'][temp_df.FEATURE.str.contains('Facebook Collab')]=7.0
        temp_df['lower_range'][temp_df.FEATURE.str.contains('Facebook Collab')]=0.0
            
        temp_df['upper_range'][temp_df.FEATURE.str.contains('AMS Product Search')]=2.77
        temp_df['lower_range'][temp_df.FEATURE.str.contains('AMS Product Search')]=2.36
            
        temp_df['upper_range'][temp_df.FEATURE.str.contains('AMS Brand Search')]=0.42
        temp_df['lower_range'][temp_df.FEATURE.str.contains('AMS Brand Search')]=0.31
            
            
            
        #temp_df['upper_range'][temp_df.FEATURE.str.contains('JBP Spends (Amazon)')]=10.13
        #temp_df['lower_range'][temp_df.FEATURE.str.contains('JBP Spends (Amazon)')]=7.75
        #temp_df['upper_range'][temp_df.FEATURE.str.contains('JBP Spends (Flipkart)')]=16.69
        #temp_df['lower_range'][temp_df.FEATURE.str.contains('JBP Spends (Flipkart)')]=9.65
        #temp_df['upper_range'][temp_df.FEATURE.str.contains('JBP Spends (Big Basket)')]=19.87
        #temp_df['lower_range'][temp_df.FEATURE.str.contains('JBP Spends (Big Basket)')]=13.48

        
        
        lower_range_tot_spend = temp_df['lower_range'].sum()
        print("Lower range")
        print(lower_range_tot_spend)
        upper_range_tot_spend = temp_df['upper_range'].sum()
        print("Upper")
        print(upper_range_tot_spend)
        
        
        ###################################################################################
    else: 
        
            if event_tag == 1:
                Total_spend =  sim_input[sim_input['Event_tag'] == 1]['SPEND'].sum()
                Total_value = sim_input[sim_input['Event_tag'] == 1]['VALUE'].sum()
                print("Priniting Total")
                print(Total_spend)
                print(Total_value)
                lower_range_tot_spend = 9
                if float(change_value) <=1.10:
                    upper_range_tot_spend = 66
                    
                else:
                    upper_range_tot_spend = 77
                    
            else:
                Total_spend =  sim_input[sim_input['Event_tag'] == 2]['SPEND'].sum()
                Total_value = sim_input[sim_input['Event_tag'] == 2]['VALUE'].sum()
                #lower_range_tot_spend = 43.6
                if float(change_value) <=1.10:
                    upper_range_tot_spend = 66
                else:
                    upper_range_tot_spend = 69
                
                
            temp_df['upper_range'][temp_df.FEATURE.str.contains('YouTube')]=18.67
            temp_df['lower_range'][temp_df.FEATURE.str.contains('YouTube')]=7.12*change_value
            
            temp_df['upper_range'][temp_df.FEATURE.str.contains('G Adwords')]=9.11
            temp_df['lower_range'][temp_df.FEATURE.str.contains('G Adwords')]=0.25*change_value
            
            temp_df['upper_range'][temp_df.FEATURE.str.contains('Facebook')]=8.35
            temp_df['lower_range'][temp_df.FEATURE.str.contains('Facebook')]=2.02*change_value
                      
            temp_df['upper_range'][temp_df.FEATURE.str.contains('Facebook Collab')]=9.23
            temp_df['lower_range'][temp_df.FEATURE.str.contains('Facebook Collab')]=0.0*change_value
                
            temp_df['upper_range'][temp_df.FEATURE.str.contains('AMS Product Search')]=4.75
            temp_df['lower_range'][temp_df.FEATURE.str.contains('AMS Product Search')]=3.46*change_value
            
            temp_df['upper_range'][temp_df.FEATURE.str.contains('AMS Brand Search')]=1.13
            temp_df['lower_range'][temp_df.FEATURE.str.contains('AMS Brand Search')]=0.09*change_value
                
                
                
            #temp_df['upper_range'][temp_df.FEATURE.str.contains('JBP Spends (Amazon)')]=11.47
            #temp_df['lower_range'][temp_df.FEATURE.str.contains('JBP Spends (Amazon)')]=8.92*change_value
            #temp_df['upper_range'][temp_df.FEATURE.str.contains('JBP Spends (Flipkart)')]=11.32
            #temp_df['lower_range'][temp_df.FEATURE.str.contains('JBP Spends (Flipkart)')]=7.10*change_value
            #temp_df['upper_range'][temp_df.FEATURE.str.contains('JBP Spends (Big Basket)')]=21.29
            #temp_df['lower_range'][temp_df.FEATURE.str.contains('JBP Spends (Big Basket)')]=19.05*change_value
                
                 
                
        
    spend_data= temp_df.copy()
    print("#################### Spend data ############################")
    print(spend_data)
    prob=LpProblem("Spend Constant Scenario Livon",LpMinimize)


    #creating LP variables
    spend_variables = LpVariable.dicts("spend_variable",[i for i in spend_data.FEATURE] ,lowBound=0,cat='Continuous')
    print("###############Spend variables#######################")
    print(spend_variables)

    #  forming mimima function 
    model_coeff = dict(zip(spend_data.FEATURE,spend_data.ROI))
    #prob += lpSum([model_coeff[i]*spend_variables[i] for i in spend_data.FEATURE])>= change_value*0.99*Total_spend


    prob += lpSum([spend_variables[i] for i in spend_data.FEATURE])  
   
 
#     prob += lpSum([spend_variables[i] for i in spend_data.FEATURE]) >= change_value*0.99*Total_spend
#     prob += lpSum([spend_variables[i] for i in spend_data.FEATURE]) <=change_value*1.01*Total_spend

    # Forming LP equations with constraints
    for i,row in spend_data.iterrows():
    #         print(row['spend_type'])
        prob+=lpSum(spend_variables[row["FEATURE"]])>=row['lower_range']
        prob+=lpSum(spend_variables[row["FEATURE"]])<=row['upper_range']
        
    #prob += lpSum([spend_variables[i] for i in spend_data.FEATURE]) >= lower_range_tot_spend
    prob += lpSum([spend_variables[i] for i in spend_data.FEATURE]) <= upper_range_tot_spend    
    
    prob += lpSum([model_coeff[i]*spend_variables[i] for i in spend_data.FEATURE])>= change_value*0.99*Total_value
    prob += lpSum([spend_variables[i] for i in spend_data.FEATURE]) <= change_value*1.01*Total_value
    #solving LP 
    print(prob)
    prob.solve()

    print("Status:", LpStatus[prob.status])
    #     print(prob)

    #getting Spend
    new_spend={}
    variables=dict([(str(value), key) for key, value in spend_variables.items()])
    print(variables)
    for v in prob.variables():
        if v.varValue>0:
            print(v.name[15:], "=", v.varValue)
#             print(v.name)
#             print(variables[v.name])
            new_spend[variables[v.name]]=v.varValue

    
    #Analysing Output
    spend_data["new_spend"]=0.0
    

    for i,v in new_spend.items():
        spend_data["new_spend"][spend_data.FEATURE==i]=v
        
    

    spend_data["new_bpm"]=spend_data.new_spend*spend_data.ROI
    
    print('---------------Overview-------------------')
    print("EARLIER SPEND: {}".format(Total_spend))
    print("NEW SPEND: {} increased/decreased by {} %".format(spend_data['new_spend'].sum(),round((spend_data['new_spend'].sum()-Total_spend)/Total_spend,4)*100))
    print('EXISTING VALUE: {}'.format(Total_value))
    print('NEW VALUE: {} increased/decreased by {}%'.format(spend_data.new_bpm.sum(),round((spend_data.new_bpm.sum()-Total_value)/Total_value,4)*100))
    # spend_data.replace({'FEATURE' : { 'GOOGLE_DISPLAY_SPEND' : 'Display', 'AMS SEARCH SPEND' : 'AMS Search Product', 'JBP_SPEND' : 'JBP Spends', 
    #                      'YOUTUBE_SPEND': 'YT', 'INSTAGRAM_SPEND': 'IG', 'FACEBOOK_SPEND': 'FB', 'GADS_SPEND': 'G adwords',  'AMS_SPON_DISPLAY_SPEND': 'AMS Search Display'}}, inplace = True)
    spend_data_new_spend = spend_data[['FEATURE', 'new_spend']]
    #spend_data_new_spend['new_spend'] = spend_data_new_spend['new_spend']
    
    
    
    return(spend_data_new_spend.copy())

# %%
b= liner_programming_scenario(sim_input, change_value =1.0, event_tag = 0)
# Out:
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 65.4764310248
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 66.7991872072
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 2.4598371
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 22.849837100000002 increased/decreased by -24.7 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 65.476431112 increased/decreased by -1.0%

# %%
b= liner_programming_scenario(sim_input, change_value =1.0, event_tag = 0)
# Out:
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 65.4764310248
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 66.7991872072
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 2.4598371
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 22.849837100000002 increased/decreased by -24.7 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 65.476431112 increased/decreased by -1.0%

# %%
format1 = {'Format':['Youtube Spend ', 'Google Display Spend ', 'G Adwords Spend ', 'Facebook Spend  ', 
                     'Instagram Spend ', np.NaN, np.NaN, 'AMS Search Display ', 'AMS Search Product ', 'AMS Search Brand ',
                 'AMS Display ', np.NaN, np.NaN, np.NaN, np.NaN, 'JBP Spends', np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN,
                 np.NaN, np.NaN, np.NaN, np.NaN]}

format1 =pd.DataFrame(format1)

# %%
##### Event Output
Output_event = pd.DataFrame()
outputs_event = pd.DataFrame(sim_input.FEATURE.unique())
outputs_event.columns = ['FEATURE']
for i in np.arange(1, 2.05, 0.05):
    print("############ change ##########")
    print(i)
    b= liner_programming_scenario(sim_input, change_value = i, event_tag = 1)
    col_name = round(i,2)
    b.rename(columns = {'new_spend': col_name}, inplace = True)
    b.drop('FEATURE', axis =1, inplace = True)
    print(b)
    outputs_event= pd.concat([outputs_event, b], axis =1)
# Out:
# ############ change ##########
# 1.0
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35         2.02
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    9.11         0.25
# 3              YouTube Spend  2.30                   18.67         7.12
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    9.23         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    1.13         0.09
# 9   AMS Product Search Spend  5.00                    4.75         3.46
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.02
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.25
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 7.12
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.09
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 3.46
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 70
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 56.6257096416
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 57.7696633717
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 1.1198537
# Facebook_Spend = 2.02
# G_Adwords_Spend = 0.25
# YouTube_Spend = 7.12
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 16.3898537 increased/decreased by -36.83 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 56.625709463999996 increased/decreased by -1.0%
#          1.0
# 0   2.020000
# 1   0.000000
# 2   0.250000
# 3   7.120000
# 4   0.000000
# 5   1.119854
# 6   0.000000
# 7   0.000000
# 8   1.130000
# 9   4.750000
# 10  0.000000
# ############ change ##########
# 1.05
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35       2.1210
# 1            Instagram Spend  0.00         ns         0.00       0.0000
# 2            G Adwords Spend  0.44                    9.11       0.2625
# 3              YouTube Spend  2.30                   18.67       7.4760
# 4              Display Spend  0.00         ns         0.00       0.0000
# 5      Facebook Collab Spend  4.72                    9.23       0.0000
# 6     Instagram Collab Spend  0.00         ns         0.00       0.0000
# 7          AMS Display Spend  0.00         ns         0.00       0.0000
# 8     AMS Brand Search Spend  5.00                    1.13       0.0945
# 9   AMS Product Search Spend  5.00                    4.75       3.6330
# 10  AMS Search Display Spend  0.00         ns         0.00       0.0000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.121
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.2625
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 7.476
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.0945
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 3.633
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 70
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 59.4569951237
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 60.6581465403
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 1.4872871
# Facebook_Spend = 2.121
# G_Adwords_Spend = 0.2625
# YouTube_Spend = 7.476
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 17.2267871 increased/decreased by -33.6 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 59.456995112 increased/decreased by 3.95%
#         1.05
# 0   2.121000
# 1   0.000000
# 2   0.262500
# 3   7.476000
# 4   0.000000
# 5   1.487287
# 6   0.000000
# 7   0.000000
# 8   1.130000
# 9   4.750000
# 10  0.000000
# ############ change ##########
# 1.1
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35        2.222
# 1            Instagram Spend  0.00         ns         0.00        0.000
# 2            G Adwords Spend  0.44                    9.11        0.275
# 3              YouTube Spend  2.30                   18.67        7.832
# 4              Display Spend  0.00         ns         0.00        0.000
# 5      Facebook Collab Spend  4.72                    9.23        0.000
# 6     Instagram Collab Spend  0.00         ns         0.00        0.000
# 7          AMS Display Spend  0.00         ns         0.00        0.000
# 8     AMS Brand Search Spend  5.00                    1.13        0.099
# 9   AMS Product Search Spend  5.00                    4.75        3.806
# 10  AMS Search Display Spend  0.00         ns         0.00        0.000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.222
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.275
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 7.832
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.099
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 3.806
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 70
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 62.2882806058
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 63.5466297089
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 1.8547205
# Facebook_Spend = 2.222
# G_Adwords_Spend = 0.275
# YouTube_Spend = 7.832
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 18.0637205 increased/decreased by -30.37 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 62.28828076 increased/decreased by 8.9%
#         1.1
# 0   2.22200
# 1   0.00000
# 2   0.27500
# 3   7.83200
# 4   0.00000
# 5   1.85472
# 6   0.00000
# 7   0.00000
# 8   1.13000
# 9   4.75000
# 10  0.00000
# ############ change ##########
# 1.1500000000000001
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35       2.3230
# 1            Instagram Spend  0.00         ns         0.00       0.0000
# 2            G Adwords Spend  0.44                    9.11       0.2875
# 3              YouTube Spend  2.30                   18.67       8.1880
# 4              Display Spend  0.00         ns         0.00       0.0000
# 5      Facebook Collab Spend  4.72                    9.23       0.0000
# 6     Instagram Collab Spend  0.00         ns         0.00       0.0000
# 7          AMS Display Spend  0.00         ns         0.00       0.0000
# 8     AMS Brand Search Spend  5.00                    1.13       0.1035
# 9   AMS Product Search Spend  5.00                    4.75       3.9790
# 10  AMS Search Display Spend  0.00         ns         0.00       0.0000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.323
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.2875
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 8.188
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.1035
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 3.979
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 65.1195660878
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 66.4351128775
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 2.2221538
# Facebook_Spend = 2.323
# G_Adwords_Spend = 0.2875
# YouTube_Spend = 8.188
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 18.9006538 increased/decreased by -27.150000000000002 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 65.119565936 increased/decreased by 13.850000000000001%
#         1.15
# 0   2.323000
# 1   0.000000
# 2   0.287500
# 3   8.188000
# 4   0.000000
# 5   2.222154
# 6   0.000000
# 7   0.000000
# 8   1.130000
# 9   4.750000
# 10  0.000000
# ############ change ##########
# 1.2000000000000002
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35        2.424
# 1            Instagram Spend  0.00         ns         0.00        0.000
# 2            G Adwords Spend  0.44                    9.11        0.300
# 3              YouTube Spend  2.30                   18.67        8.544
# 4              Display Spend  0.00         ns         0.00        0.000
# 5      Facebook Collab Spend  4.72                    9.23        0.000
# 6     Instagram Collab Spend  0.00         ns         0.00        0.000
# 7          AMS Display Spend  0.00         ns         0.00        0.000
# 8     AMS Brand Search Spend  5.00                    1.13        0.108
# 9   AMS Product Search Spend  5.00                    4.75        4.152
# 10  AMS Search Display Spend  0.00         ns         0.00        0.000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.424
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.3
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 8.544
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.108
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 4.152
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 67.9508515699
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 69.3235960461
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 2.5895872
# Facebook_Spend = 2.424
# G_Adwords_Spend = 0.3
# YouTube_Spend = 8.544
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 19.7375872 increased/decreased by -23.919999999999998 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 67.95085158399999 increased/decreased by 18.8%
#          1.2
# 0   2.424000
# 1   0.000000
# 2   0.300000
# 3   8.544000
# 4   0.000000
# 5   2.589587
# 6   0.000000
# 7   0.000000
# 8   1.130000
# 9   4.750000
# 10  0.000000
# ############ change ##########
# 1.2500000000000002
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35       2.5250
# 1            Instagram Spend  0.00         ns         0.00       0.0000
# 2            G Adwords Spend  0.44                    9.11       0.3125
# 3              YouTube Spend  2.30                   18.67       8.9000
# 4              Display Spend  0.00         ns         0.00       0.0000
# 5      Facebook Collab Spend  4.72                    9.23       0.0000
# 6     Instagram Collab Spend  0.00         ns         0.00       0.0000
# 7          AMS Display Spend  0.00         ns         0.00       0.0000
# 8     AMS Brand Search Spend  5.00                    1.13       0.1125
# 9   AMS Product Search Spend  5.00                    4.75       4.3250
# 10  AMS Search Display Spend  0.00         ns         0.00       0.0000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.525
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.3125
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 8.9
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.1125
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 4.325
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 70.782137052
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 72.2120792147
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 2.9570206
# Facebook_Spend = 2.525
# G_Adwords_Spend = 0.3125
# YouTube_Spend = 8.9
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 20.5745206 increased/decreased by -20.7 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 70.782137232 increased/decreased by 23.75%
#         1.25
# 0   2.525000
# 1   0.000000
# 2   0.312500
# 3   8.900000
# 4   0.000000
# 5   2.957021
# 6   0.000000
# 7   0.000000
# 8   1.130000
# 9   4.750000
# 10  0.000000
# ############ change ##########
# 1.3000000000000003
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35        2.626
# 1            Instagram Spend  0.00         ns         0.00        0.000
# 2            G Adwords Spend  0.44                    9.11        0.325
# 3              YouTube Spend  2.30                   18.67        9.256
# 4              Display Spend  0.00         ns         0.00        0.000
# 5      Facebook Collab Spend  4.72                    9.23        0.000
# 6     Instagram Collab Spend  0.00         ns         0.00        0.000
# 7          AMS Display Spend  0.00         ns         0.00        0.000
# 8     AMS Brand Search Spend  5.00                    1.13        0.117
# 9   AMS Product Search Spend  5.00                    4.75        4.498
# 10  AMS Search Display Spend  0.00         ns         0.00        0.000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.626
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.325
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 9.256
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.117
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 4.498
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 73.6134225341
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 75.1005623833
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 3.3244539
# Facebook_Spend = 2.626
# G_Adwords_Spend = 0.325
# YouTube_Spend = 9.256
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 21.411453899999998 increased/decreased by -17.47 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 73.61342240799999 increased/decreased by 28.7%
#          1.3
# 0   2.626000
# 1   0.000000
# 2   0.325000
# 3   9.256000
# 4   0.000000
# 5   3.324454
# 6   0.000000
# 7   0.000000
# 8   1.130000
# 9   4.750000
# 10  0.000000
# ############ change ##########
# 1.3500000000000003
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35       2.7270
# 1            Instagram Spend  0.00         ns         0.00       0.0000
# 2            G Adwords Spend  0.44                    9.11       0.3375
# 3              YouTube Spend  2.30                   18.67       9.6120
# 4              Display Spend  0.00         ns         0.00       0.0000
# 5      Facebook Collab Spend  4.72                    9.23       0.0000
# 6     Instagram Collab Spend  0.00         ns         0.00       0.0000
# 7          AMS Display Spend  0.00         ns         0.00       0.0000
# 8     AMS Brand Search Spend  5.00                    1.13       0.1215
# 9   AMS Product Search Spend  5.00                    4.75       4.6710
# 10  AMS Search Display Spend  0.00         ns         0.00       0.0000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.727
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.3375
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 9.612
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.1215
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 4.671
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 76.4447080162
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 77.9890455518
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 3.6918873
# ...
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 3.838
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.475
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 13.528
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.171
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 6.574
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 107.588848319
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 109.762360406
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Infeasible
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 7.777934
# Facebook_Spend = 3.838
# YouTube_Spend = 13.528
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 31.023934 increased/decreased by 19.580000000000002 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 107.58884848000001 increased/decreased by 88.1%
#           1.9
# 0    3.838000
# 1    0.000000
# 2    0.000000
# 3   13.528000
# 4    0.000000
# 5    7.777934
# 6    0.000000
# 7    0.000000
# 8    1.130000
# 9    4.750000
# 10   0.000000
# ############ change ##########
# 1.9500000000000008
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35       3.9390
# 1            Instagram Spend  0.00         ns         0.00       0.0000
# 2            G Adwords Spend  0.44                    9.11       0.4875
# 3              YouTube Spend  2.30                   18.67      13.8840
# 4              Display Spend  0.00         ns         0.00       0.0000
# 5      Facebook Collab Spend  4.72                    9.23       0.0000
# 6     Instagram Collab Spend  0.00         ns         0.00       0.0000
# 7          AMS Display Spend  0.00         ns         0.00       0.0000
# 8     AMS Brand Search Spend  5.00                    1.13       0.1755
# 9   AMS Product Search Spend  5.00                    4.75       6.7470
# 10  AMS Search Display Spend  0.00         ns         0.00       0.0000
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 3.939
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.4875
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 13.884
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.1755
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 6.747
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 110.420133801
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 112.650843575
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Infeasible
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 8.1465326
# Facebook_Spend = 3.939
# YouTube_Spend = 13.884
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 31.8495326 increased/decreased by 22.759999999999998 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 110.42013387200001 increased/decreased by 93.05%
#          1.95
# 0    3.939000
# 1    0.000000
# 2    0.000000
# 3   13.884000
# 4    0.000000
# 5    8.146533
# 6    0.000000
# 7    0.000000
# 8    1.130000
# 9    4.750000
# 10   0.000000
# ############ change ##########
# 2.000000000000001
# Priniting Total
# 25.94400883333333
# 57.19768650666667
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                    8.35         4.04
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    9.11         0.50
# 3              YouTube Spend  2.30                   18.67        14.24
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    9.23         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    1.13         0.18
# 9   AMS Product Search Spend  5.00                    4.75         6.92
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 4.04
#
# _C2: spend_variable_Facebook_Spend <= 8.35
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 0.5
#
# _C6: spend_variable_G_Adwords_Spend <= 9.11
#
# _C7: spend_variable_YouTube_Spend >= 14.24
#
# _C8: spend_variable_YouTube_Spend <= 18.67
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 9.23
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.18
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 1.13
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 6.92
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 4.75
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 77
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 113.251419283
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 115.539326743
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Infeasible
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 1.13
# AMS_Product_Search_Spend = 4.75
# Facebook_Collab_Spend = 8.5151312
# Facebook_Spend = 4.04
# YouTube_Spend = 14.24
# ---------------Overview-------------------
# EARLIER SPEND: 25.94400883333333
# NEW SPEND: 32.675131199999996 increased/decreased by 25.94 %
# EXISTING VALUE: 57.19768650666667
# NEW VALUE: 113.251419264 increased/decreased by 98.0%
#           2.0
# 0    4.040000
# 1    0.000000
# 2    0.000000
# 3   14.240000
# 4    0.000000
# 5    8.515131
# 6    0.000000
# 7    0.000000
# 8    1.130000
# 9    4.750000
# 10   0.000000

# %%
outputs_event
# Out:
#                      FEATURE       1.0      1.05      1.1      1.15       1.2  \
# 0             Facebook Spend  2.020000  2.121000  2.22200  2.323000  2.424000
# 1            Instagram Spend  0.000000  0.000000  0.00000  0.000000  0.000000
# 2            G Adwords Spend  0.250000  0.262500  0.27500  0.287500  0.300000
# 3              YouTube Spend  7.120000  7.476000  7.83200  8.188000  8.544000
# 4              Display Spend  0.000000  0.000000  0.00000  0.000000  0.000000
# 5      Facebook Collab Spend  1.119854  1.487287  1.85472  2.222154  2.589587
# 6     Instagram Collab Spend  0.000000  0.000000  0.00000  0.000000  0.000000
# 7          AMS Display Spend  0.000000  0.000000  0.00000  0.000000  0.000000
# 8     AMS Brand Search Spend  1.130000  1.130000  1.13000  1.130000  1.130000
# 9   AMS Product Search Spend  4.750000  4.750000  4.75000  4.750000  4.750000
# 10  AMS Search Display Spend  0.000000  0.000000  0.00000  0.000000  0.000000
#
#         1.25       1.3      1.35       1.4       1.45        1.5       1.55  \
# 0   2.525000  2.626000  2.727000  2.828000   2.929000   3.030000   3.131000
# 1   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000   0.000000
# 2   0.312500  0.325000  0.337500  0.350000   0.000000   0.000000   0.000000
# 3   8.900000  9.256000  9.612000  9.968000  10.324000  10.680000  11.036000
# 4   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000   0.000000
# 5   2.957021  3.324454  3.691887  4.059321   4.460546   4.829145   5.197744
# 6   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000   0.000000
# 7   0.000000  0.000000  0.000000  0.000000   0.000000   0.000000   0.000000
# 8   1.130000  1.130000  1.130000  1.130000   1.130000   1.130000   1.130000
# 9   4.750000  4.750000  4.750000  4.750000   4.750000   4.750000   4.750000
# 10  0.000000  0.000000  0.000000  0.000000   0.000000   0.000000   0.000000
#
#           1.6       1.65       1.7       1.75        1.8       1.85  \
# 0    3.232000   3.333000   3.43400   3.535000   3.636000   3.737000
# 1    0.000000   0.000000   0.00000   0.000000   0.000000   0.000000
# 2    0.000000   0.000000   0.00000   0.000000   0.000000   0.000000
# 3   11.392000  11.748000  12.10400  12.460000  12.816000  13.172000
# 4    0.000000   0.000000   0.00000   0.000000   0.000000   0.000000
# 5    5.566342   5.934941   6.30354   6.672138   7.040737   7.409335
# 6    0.000000   0.000000   0.00000   0.000000   0.000000   0.000000
# 7    0.000000   0.000000   0.00000   0.000000   0.000000   0.000000
# 8    1.130000   1.130000   1.13000   1.130000   1.130000   1.130000
# 9    4.750000   4.750000   4.75000   4.750000   4.750000   4.750000
# 10   0.000000   0.000000   0.00000   0.000000   0.000000   0.000000
#
#           1.9       1.95        2.0
# 0    3.838000   3.939000   4.040000
# 1    0.000000   0.000000   0.000000
# 2    0.000000   0.000000   0.000000
# 3   13.528000  13.884000  14.240000
# 4    0.000000   0.000000   0.000000
# 5    7.777934   8.146533   8.515131
# 6    0.000000   0.000000   0.000000
# 7    0.000000   0.000000   0.000000
# 8    1.130000   1.130000   1.130000
# 9    4.750000   4.750000   4.750000
# 10   0.000000   0.000000   0.000000

# %%
##### Super Event Output
#Output_sup_event = pd.DataFrame()
#Output_sup_event = pd.DataFrame(sim_input.FEATURE.unique())
#Output_sup_event.columns = ['FEATURE']
#for i in np.arange(1, 2.01, 0.05):
#    print("############ change ##########")
#    print(i)
#    b= liner_programming_scenario(sim_input, change_value = i, event_tag = 2)
#    col_name = round(i,2)
#    b.rename(columns = {'new_spend': col_name}, inplace = True)
#    b.drop('FEATURE', axis =1, inplace = True)
#    print(b)
#    Output_sup_event= pd.concat([Output_sup_event, b], axis =1)

# %%
#Output_sup_event

# %%
##### Non non_event Output

outputs_non_event = pd.DataFrame(sim_input.FEATURE.unique())
outputs_non_event.columns = ['FEATURE']
for i in np.arange(1, 2.01, 0.05):
    print("############ change ##########")
    print(i)
    b= liner_programming_scenario(sim_input, change_value = i, event_tag=0 )
    col_name = round(i,2)
    b.rename(columns = {'new_spend': col_name}, inplace = True)
    b.drop('FEATURE', axis =1, inplace = True)
    print(b)
    outputs_non_event= pd.concat([outputs_non_event, b], axis =1)
# Out:
# ############ change ##########
# 1.0
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 65.4764310248
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 66.7991872072
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 2.4598371
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 22.849837100000002 increased/decreased by -24.7 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 65.476431112 increased/decreased by -1.0%
#           1.0
# 0    2.400000
# 1    0.000000
# 2    1.400000
# 3   13.400000
# 4    0.000000
# 5    2.459837
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.05
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 68.7502525761
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 70.1391465675
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 3.1534433
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 23.5434433 increased/decreased by -22.42 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 68.75025237599999 increased/decreased by 3.95%
#          1.05
# 0    2.400000
# 1    0.000000
# 2    1.400000
# 3   13.400000
# 4    0.000000
# 5    3.153443
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.1
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 72.0240741273
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 73.4791059279
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 3.8470496
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 24.237049600000002 increased/decreased by -20.13 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 72.024074112 increased/decreased by 8.9%
#          1.1
# 0    2.40000
# 1    0.00000
# 2    1.40000
# 3   13.40000
# 4    0.00000
# 5    3.84705
# 6    0.00000
# 7    0.00000
# 8    0.42000
# 9    2.77000
# 10   0.00000
# ############ change ##########
# 1.1500000000000001
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 75.2978956786
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 76.8190652882
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 4.5406559
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 24.9306559 increased/decreased by -17.849999999999998 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 75.297895848 increased/decreased by 13.850000000000001%
#          1.15
# 0    2.400000
# 1    0.000000
# 2    1.400000
# 3   13.400000
# 4    0.000000
# 5    4.540656
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.2000000000000002
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 78.5717172298
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 80.1590246486
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 5.2342621
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 25.6242621 increased/decreased by -15.559999999999999 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 78.57171711199999 increased/decreased by 18.8%
#           1.2
# 0    2.400000
# 1    0.000000
# 2    1.400000
# 3   13.400000
# 4    0.000000
# 5    5.234262
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.2500000000000002
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 81.8455387811
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 83.498984009
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 5.9278684
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 26.317868400000002 increased/decreased by -13.270000000000001 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 81.84553884799999 increased/decreased by 23.75%
#          1.25
# 0    2.400000
# 1    0.000000
# 2    1.400000
# 3   13.400000
# 4    0.000000
# 5    5.927868
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.3000000000000003
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 85.1193603323
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 86.8389433693
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 6.6214746
# Facebook_Spend = 2.4
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 27.0114746 increased/decreased by -10.99 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 85.11936011199998 increased/decreased by 28.7%
#           1.3
# 0    2.400000
# 1    0.000000
# 2    1.400000
# 3   13.400000
# 4    0.000000
# 5    6.621475
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.3500000000000003
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 88.3931818835
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 90.1789027297
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 7.0
# Facebook_Spend = 2.9508081
# G_Adwords_Spend = 1.4
# YouTube_Spend = 13.4
# ...
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 124.405218947
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 126.918455694
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 7.0
# Facebook_Spend = 10.6
# G_Adwords_Spend = 1.4
# YouTube_Spend = 20.077921
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 42.267921 increased/decreased by 39.290000000000006 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 124.40521829999997 increased/decreased by 88.1%
#           1.9
# 0   10.600000
# 1    0.000000
# 2    1.400000
# 3   20.077921
# 4    0.000000
# 5    7.000000
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 1.9500000000000008
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 127.679040498
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 130.258415054
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 7.0
# Facebook_Spend = 10.6
# G_Adwords_Spend = 1.4
# YouTube_Spend = 21.501322
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 43.691322 increased/decreased by 43.980000000000004 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 127.67904059999998 increased/decreased by 93.05%
#          1.95
# 0   10.600000
# 1    0.000000
# 2    1.400000
# 3   21.501322
# 4    0.000000
# 5    7.000000
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000
# ############ change ##########
# 2.000000000000001
# Lower range
# 19.869999999999997
# Upper
# 76.19
# #################### Spend data ############################
#                      FEATURE   ROI spend_type  upper_range  lower_range
# 0             Facebook Spend  2.70                   10.60         2.40
# 1            Instagram Spend  0.00         ns         0.00         0.00
# 2            G Adwords Spend  0.44                    7.20         1.40
# 3              YouTube Spend  2.30                   48.20        13.40
# 4              Display Spend  0.00         ns         0.00         0.00
# 5      Facebook Collab Spend  4.72                    7.00         0.00
# 6     Instagram Collab Spend  0.00         ns         0.00         0.00
# 7          AMS Display Spend  0.00         ns         0.00         0.00
# 8     AMS Brand Search Spend  5.00                    0.42         0.31
# 9   AMS Product Search Spend  5.00                    2.77         2.36
# 10  AMS Search Display Spend  0.00         ns         0.00         0.00
# ###############Spend variables#######################
# {'Facebook Spend': spend_variable_Facebook_Spend, 'Instagram Spend': spend_variable_Instagram_Spend, 'G Adwords Spend': spend_variable_G_Adwords_Spend, 'YouTube Spend': spend_variable_YouTube_Spend, 'Display Spend': spend_variable_Display_Spend, 'Facebook Collab Spend': spend_variable_Facebook_Collab_Spend, 'Instagram Collab Spend': spend_variable_Instagram_Collab_Spend, 'AMS Display Spend': spend_variable_AMS_Display_Spend, 'AMS Brand Search Spend': spend_variable_AMS_Brand_Search_Spend, 'AMS Product Search Spend': spend_variable_AMS_Product_Search_Spend, 'AMS Search Display Spend': spend_variable_AMS_Search_Display_Spend}
# Spend_Constant_Scenario_Livon:
# MINIMIZE
# 1*spend_variable_AMS_Brand_Search_Spend + 1*spend_variable_AMS_Display_Spend + 1*spend_variable_AMS_Product_Search_Spend + 1*spend_variable_AMS_Search_Display_Spend + 1*spend_variable_Display_Spend + 1*spend_variable_Facebook_Collab_Spend + 1*spend_variable_Facebook_Spend + 1*spend_variable_G_Adwords_Spend + 1*spend_variable_Instagram_Collab_Spend + 1*spend_variable_Instagram_Spend + 1*spend_variable_YouTube_Spend + 0
# SUBJECT TO
# _C1: spend_variable_Facebook_Spend >= 2.4
#
# _C2: spend_variable_Facebook_Spend <= 10.6
#
# _C3: spend_variable_Instagram_Spend >= 0
#
# _C4: spend_variable_Instagram_Spend <= 0
#
# _C5: spend_variable_G_Adwords_Spend >= 1.4
#
# _C6: spend_variable_G_Adwords_Spend <= 7.2
#
# _C7: spend_variable_YouTube_Spend >= 13.4
#
# _C8: spend_variable_YouTube_Spend <= 48.2
#
# _C9: spend_variable_Display_Spend >= 0
#
# _C10: spend_variable_Display_Spend <= 0
#
# _C11: spend_variable_Facebook_Collab_Spend >= 0
#
# _C12: spend_variable_Facebook_Collab_Spend <= 7
#
# _C13: spend_variable_Instagram_Collab_Spend >= 0
#
# _C14: spend_variable_Instagram_Collab_Spend <= 0
#
# _C15: spend_variable_AMS_Display_Spend >= 0
#
# _C16: spend_variable_AMS_Display_Spend <= 0
#
# _C17: spend_variable_AMS_Brand_Search_Spend >= 0.31
#
# _C18: spend_variable_AMS_Brand_Search_Spend <= 0.42
#
# _C19: spend_variable_AMS_Product_Search_Spend >= 2.36
#
# _C20: spend_variable_AMS_Product_Search_Spend <= 2.77
#
# _C21: spend_variable_AMS_Search_Display_Spend >= 0
#
# _C22: spend_variable_AMS_Search_Display_Spend <= 0
#
# _C23: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend <= 76.19
#
# _C24: 5 spend_variable_AMS_Brand_Search_Spend
#  + 5 spend_variable_AMS_Product_Search_Spend
#  + 4.72 spend_variable_Facebook_Collab_Spend
#  + 2.7 spend_variable_Facebook_Spend + 0.44 spend_variable_G_Adwords_Spend
#  + 2.3 spend_variable_YouTube_Spend >= 130.95286205
#
# _C25: spend_variable_AMS_Brand_Search_Spend + spend_variable_AMS_Display_Spend
#  + spend_variable_AMS_Product_Search_Spend
#  + spend_variable_AMS_Search_Display_Spend + spend_variable_Display_Spend
#  + spend_variable_Facebook_Collab_Spend + spend_variable_Facebook_Spend
#  + spend_variable_G_Adwords_Spend + spend_variable_Instagram_Collab_Spend
#  + spend_variable_Instagram_Spend + spend_variable_YouTube_Spend
#  <= 133.598374414
#
# VARIABLES
# spend_variable_AMS_Brand_Search_Spend Continuous
# spend_variable_AMS_Display_Spend Continuous
# spend_variable_AMS_Product_Search_Spend Continuous
# spend_variable_AMS_Search_Display_Spend Continuous
# spend_variable_Display_Spend Continuous
# spend_variable_Facebook_Collab_Spend Continuous
# spend_variable_Facebook_Spend Continuous
# spend_variable_G_Adwords_Spend Continuous
# spend_variable_Instagram_Collab_Spend Continuous
# spend_variable_Instagram_Spend Continuous
# spend_variable_YouTube_Spend Continuous
#
# Status: Optimal
# {'spend_variable_Facebook_Spend': 'Facebook Spend', 'spend_variable_Instagram_Spend': 'Instagram Spend', 'spend_variable_G_Adwords_Spend': 'G Adwords Spend', 'spend_variable_YouTube_Spend': 'YouTube Spend', 'spend_variable_Display_Spend': 'Display Spend', 'spend_variable_Facebook_Collab_Spend': 'Facebook Collab Spend', 'spend_variable_Instagram_Collab_Spend': 'Instagram Collab Spend', 'spend_variable_AMS_Display_Spend': 'AMS Display Spend', 'spend_variable_AMS_Brand_Search_Spend': 'AMS Brand Search Spend', 'spend_variable_AMS_Product_Search_Spend': 'AMS Product Search Spend', 'spend_variable_AMS_Search_Display_Spend': 'AMS Search Display Spend'}
# AMS_Brand_Search_Spend = 0.42
# AMS_Product_Search_Spend = 2.77
# Facebook_Collab_Spend = 7.0
# Facebook_Spend = 10.6
# G_Adwords_Spend = 1.4
# YouTube_Spend = 22.924723
# ---------------Overview-------------------
# EARLIER SPEND: 30.345931366666665
# NEW SPEND: 45.114723000000005 increased/decreased by 48.67 %
# EXISTING VALUE: 66.137809116
# NEW VALUE: 130.95286289999999 increased/decreased by 98.0%
#           2.0
# 0   10.600000
# 1    0.000000
# 2    1.400000
# 3   22.924723
# 4    0.000000
# 5    7.000000
# 6    0.000000
# 7    0.000000
# 8    0.420000
# 9    2.770000
# 10   0.000000

# %%
outputs_non_event
# Out:
#                      FEATURE        1.0       1.05       1.1       1.15  \
# 0             Facebook Spend   2.400000   2.400000   2.40000   2.400000
# 1            Instagram Spend   0.000000   0.000000   0.00000   0.000000
# 2            G Adwords Spend   1.400000   1.400000   1.40000   1.400000
# 3              YouTube Spend  13.400000  13.400000  13.40000  13.400000
# 4              Display Spend   0.000000   0.000000   0.00000   0.000000
# 5      Facebook Collab Spend   2.459837   3.153443   3.84705   4.540656
# 6     Instagram Collab Spend   0.000000   0.000000   0.00000   0.000000
# 7          AMS Display Spend   0.000000   0.000000   0.00000   0.000000
# 8     AMS Brand Search Spend   0.420000   0.420000   0.42000   0.420000
# 9   AMS Product Search Spend   2.770000   2.770000   2.77000   2.770000
# 10  AMS Search Display Spend   0.000000   0.000000   0.00000   0.000000
#
#           1.2       1.25        1.3       1.35        1.4       1.45  \
# 0    2.400000   2.400000   2.400000   2.950808   4.163335   5.375861
# 1    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2    1.400000   1.400000   1.400000   1.400000   1.400000   1.400000
# 3   13.400000  13.400000  13.400000  13.400000  13.400000  13.400000
# 4    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 5    5.234262   5.927868   6.621475   7.000000   7.000000   7.000000
# 6    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 7    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8    0.420000   0.420000   0.420000   0.420000   0.420000   0.420000
# 9    2.770000   2.770000   2.770000   2.770000   2.770000   2.770000
# 10   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#           1.5       1.55        1.6       1.65        1.7       1.75  \
# 0    6.588388   7.800914   9.013441  10.225967  10.600000  10.600000
# 1    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2    1.400000   1.400000   1.400000   1.400000   1.400000   1.400000
# 3   13.400000  13.400000  13.400000  13.400000  14.384319  15.807719
# 4    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 5    7.000000   7.000000   7.000000   7.000000   7.000000   7.000000
# 6    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 7    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 8    0.420000   0.420000   0.420000   0.420000   0.420000   0.420000
# 9    2.770000   2.770000   2.770000   2.770000   2.770000   2.770000
# 10   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
#
#          1.8       1.85        1.9       1.95        2.0
# 0   10.60000  10.600000  10.600000  10.600000  10.600000
# 1    0.00000   0.000000   0.000000   0.000000   0.000000
# 2    1.40000   1.400000   1.400000   1.400000   1.400000
# 3   17.23112  18.654521  20.077921  21.501322  22.924723
# 4    0.00000   0.000000   0.000000   0.000000   0.000000
# 5    7.00000   7.000000   7.000000   7.000000   7.000000
# 6    0.00000   0.000000   0.000000   0.000000   0.000000
# 7    0.00000   0.000000   0.000000   0.000000   0.000000
# 8    0.42000   0.420000   0.420000   0.420000   0.420000
# 9    2.77000   2.770000   2.770000   2.770000   2.770000
# 10   0.00000   0.000000   0.000000   0.000000   0.000000

# %%
writer = pd.ExcelWriter('Simulation_Output_Vol_targeting_Saffola_Oil.xlsx', engine='xlsxwriter')

#store your dataframes in a  dict, where the key is the sheet name you want
frames = {'Event': outputs_event,
          #'Super_Event': Output_sup_event, 
          'Non_Event': outputs_non_event }

#now loop thru and put each on a specific sheet
for sheet, frame in  frames.items(): 
    frame.to_excel(writer, sheet_name = sheet, index = False)

#critical last step
writer.save()

# %%
#END#

# %%
#max_bpm_sheet = format1.merge(output_final, left_on = 'Format', right_on = 'FEATURE', how = 'left')

# %%
max_bpm_sheet.drop('Format', axis =1, inplace = True)

# %%
max_bpm_sheet.to_excel('MAX_BPM_SIMULATION.xlsx', index = False)
